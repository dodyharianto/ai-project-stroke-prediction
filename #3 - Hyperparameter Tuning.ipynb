# %%
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-2.10.1-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 7.4 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.37)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Collecting alembic
#   Downloading alembic-1.8.0-py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 65.6 MB/s
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 8.7 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.0)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.1)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.11.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.7.1)
# Collecting Mako
#   Downloading Mako-1.2.0-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 7.2 MB/s
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.1-py3-none-any.whl (29 kB)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.9.0-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 53.7 MB/s
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.1-py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 50.2 MB/s
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.3 MB/s
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (4.2.0)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=c54686db1fa76730f8f188de67594ccf7c7f9642bd82306222b8c02a918c17a5
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna
# Successfully installed Mako-1.2.0 alembic-1.8.0 autopage-0.5.1 cliff-3.10.1 cmaes-0.8.2 cmd2-2.4.1 colorlog-6.6.0 optuna-2.10.1 pbr-5.9.0 pyperclip-1.8.2 stevedore-3.5.0

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
# Analysis and Preprocessing
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# Modeling and Evaluation
from sklearn.model_selection import train_test_split, StratifiedKFold
from imblearn.over_sampling import SMOTE
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
import optuna
from lightgbm import LGBMClassifier

# %%
# df = pd.read_csv('/content/drive/MyDrive/SEMESTER 4 COURSES/Artificial Intelligence/Prototype Project/Datasets/downsampled_df.csv')
df = pd.read_csv('/content/oversampled_df.csv')
df.head()
# Out:
#    Gender       Age  Hypertension  Heart Disease  Ever Married  \
# 0       1  1.051434             0              1             1
# 1       0  0.786070             0              0             1
# 2       1  1.626390             0              1             1
# 3       0  0.255342             0              0             1
# 4       0  1.582163             1              0             1
#
#    Avg Glucose Level       Bmi  Work Type_Private  Work Type_Self-employed  \
# 0           2.706375  1.005086                  0                        0
# 1           2.121559 -0.098981                  0                        0
# 2          -0.005028  0.472536                  0                        0
# 3           1.437358  0.719327                  0                        0
# 4           1.501184 -0.631531                  0                        0
#
#    Work Type_Govt_job  Work Type_children  Work Type_Never_worked  \
# 0                   1                   0                       0
# 1                   0                   1                       0
# 2                   1                   0                       0
# 3                   1                   0                       0
# 4                   0                   1                       0
#
#    Residence Type_Urban  Residence Type_Rural  Smoking Status_formerly smoked  \
# 0                     0                     1                               0
# 1                     1                     0                               0
# 2                     1                     0                               0
# 3                     0                     1                               0
# 4                     1                     0                               0
#
#    Smoking Status_never smoked  Smoking Status_smokes  Smoking Status_Unknown  \
# 0                            1                      0                       0
# 1                            0                      1                       0
# 2                            0                      1                       0
# 3                            0                      0                       1
# 4                            0                      1                       0
#
#    Stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
X = df.drop('Stroke', axis = 1)
y = df['Stroke']

X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, random_state = 1)

# %%
def objective(trial):
    X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size = 0.2, 
                                                          stratify = y_train_full, random_state = 1)

    # Define potential hyperparameters
    params_grid = {'objective': 'binary',
        'metric': 'binary_logloss',
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-5, 100, log = True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-5, 100, log = True),
        'num_leaves': trial.suggest_int('num_leaves', 2, 5000),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'max_bin': trial.suggest_int('max_bin', 100, 500),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.2),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 200, 1000),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.4, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.4, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'n_estimators': trial.suggest_int('n_estimators', 100, 10000)}

    # Make Prediction
    lgbm = LGBMClassifier(**params_grid)
    lgbm.fit(X_train, y_train, eval_set = [(X_valid, y_valid)], verbose = 0, early_stopping_rounds = 100)
    predictions = lgbm.predict(X_valid)

    # Get the accuracy
    recall = recall_score(predictions, y_valid)
    return recall

# %%
study = optuna.create_study(direction = 'maximize')
study.optimize(objective, n_trials = 10)
# Out:
# [I 2022-06-17 04:44:25,667] A new study created in memory with name: no-name-865971ed-de9a-4a30-bbb7-d9f3bdf94ffb
# [I 2022-06-17 04:44:30,304] Trial 0 finished with value: 0.8903775883069428 and parameters: {'lambda_l1': 0.030649986480190607, 'lambda_l2': 0.013469831374964346, 'num_leaves': 386, 'max_depth': 5, 'max_bin': 337, 'learning_rate': 0.10179025996337786, 'min_data_in_leaf': 525, 'feature_fraction': 0.6413228111649174, 'bagging_fraction': 0.5153386031426539, 'bagging_freq': 3, 'min_child_samples': 94, 'n_estimators': 6753}. Best is trial 0 with value: 0.8903775883069428.
# [I 2022-06-17 04:45:01,701] Trial 1 finished with value: 0.924812030075188 and parameters: {'lambda_l1': 3.375923636525349e-05, 'lambda_l2': 2.7106218792169736e-05, 'num_leaves': 4344, 'max_depth': 14, 'max_bin': 467, 'learning_rate': 0.029737799876625354, 'min_data_in_leaf': 318, 'feature_fraction': 0.7306531087307528, 'bagging_fraction': 0.7005078027255269, 'bagging_freq': 5, 'min_child_samples': 35, 'n_estimators': 6738}. Best is trial 1 with value: 0.924812030075188.
# [I 2022-06-17 04:45:07,775] Trial 2 finished with value: 0.9292929292929293 and parameters: {'lambda_l1': 6.348647179004218e-05, 'lambda_l2': 0.021758262340227992, 'num_leaves': 3741, 'max_depth': 12, 'max_bin': 316, 'learning_rate': 0.055363226662735625, 'min_data_in_leaf': 336, 'feature_fraction': 0.7449731268786871, 'bagging_fraction': 0.859148386012616, 'bagging_freq': 5, 'min_child_samples': 10, 'n_estimators': 6221}. Best is trial 2 with value: 0.9292929292929293.
# [I 2022-06-17 04:45:08,103] Trial 3 finished with value: 0.7631578947368421 and parameters: {'lambda_l1': 26.269812934856702, 'lambda_l2': 2.059616478969508e-05, 'num_leaves': 609, 'max_depth': 7, 'max_bin': 305, 'learning_rate': 0.04288306674739814, 'min_data_in_leaf': 943, 'feature_fraction': 0.4180790816800897, 'bagging_fraction': 0.5302601875488941, 'bagging_freq': 4, 'min_child_samples': 9, 'n_estimators': 5235}. Best is trial 2 with value: 0.9292929292929293.
# [I 2022-06-17 04:45:13,065] Trial 4 finished with value: 0.8615384615384616 and parameters: {'lambda_l1': 0.04306879873286532, 'lambda_l2': 0.0005479782840487916, 'num_leaves': 3416, 'max_depth': 3, 'max_bin': 462, 'learning_rate': 0.09439373149858708, 'min_data_in_leaf': 855, 'feature_fraction': 0.40179119499166144, 'bagging_fraction': 0.9405819899657998, 'bagging_freq': 7, 'min_child_samples': 49, 'n_estimators': 5064}. Best is trial 2 with value: 0.9292929292929293.
# [I 2022-06-17 04:45:15,291] Trial 5 finished with value: 0.892459826946848 and parameters: {'lambda_l1': 4.049775195040662, 'lambda_l2': 0.002538844821058277, 'num_leaves': 3232, 'max_depth': 3, 'max_bin': 446, 'learning_rate': 0.18714619590361037, 'min_data_in_leaf': 320, 'feature_fraction': 0.9817338995553857, 'bagging_fraction': 0.43908127494370175, 'bagging_freq': 2, 'min_child_samples': 12, 'n_estimators': 2097}. Best is trial 2 with value: 0.9292929292929293.
# [I 2022-06-17 04:45:16,629] Trial 6 finished with value: 0.7897727272727273 and parameters: {'lambda_l1': 0.0006110845672155464, 'lambda_l2': 0.00039690193470925684, 'num_leaves': 3273, 'max_depth': 3, 'max_bin': 163, 'learning_rate': 0.12250760458479787, 'min_data_in_leaf': 882, 'feature_fraction': 0.8087342235489328, 'bagging_fraction': 0.44059234857414964, 'bagging_freq': 5, 'min_child_samples': 99, 'n_estimators': 6206}. Best is trial 2 with value: 0.9292929292929293.
# [I 2022-06-17 04:45:18,700] Trial 7 finished with value: 0.8302540415704388 and parameters: {'lambda_l1': 0.34177354766757934, 'lambda_l2': 98.98236728482979, 'num_leaves': 3259, 'max_depth': 5, 'max_bin': 406, 'learning_rate': 0.15888336869661632, 'min_data_in_leaf': 801, 'feature_fraction': 0.9050865709901978, 'bagging_fraction': 0.6574540116559997, 'bagging_freq': 2, 'min_child_samples': 14, 'n_estimators': 2177}. Best is trial 2 with value: 0.9292929292929293.
# [I 2022-06-17 04:45:23,686] Trial 8 finished with value: 0.9352791878172588 and parameters: {'lambda_l1': 0.0015395748402496933, 'lambda_l2': 0.5766787304983864, 'num_leaves': 2450, 'max_depth': 3, 'max_bin': 447, 'learning_rate': 0.16373463943037975, 'min_data_in_leaf': 457, 'feature_fraction': 0.554404152192108, 'bagging_fraction': 0.9260262499752487, 'bagging_freq': 4, 'min_child_samples': 17, 'n_estimators': 4980}. Best is trial 8 with value: 0.9352791878172588.
# [I 2022-06-17 04:45:27,251] Trial 9 finished with value: 0.8079545454545455 and parameters: {'lambda_l1': 10.428435666865541, 'lambda_l2': 0.014680399996541096, 'num_leaves': 3767, 'max_depth': 9, 'max_bin': 288, 'learning_rate': 0.04455207559194938, 'min_data_in_leaf': 967, 'feature_fraction': 0.9766929738328373, 'bagging_fraction': 0.83231330888399, 'bagging_freq': 3, 'min_child_samples': 81, 'n_estimators': 5628}. Best is trial 8 with value: 0.9352791878172588.

# %%
best_params = study.best_params
best_params
# Out:
# {'bagging_fraction': 0.9260262499752487,
#  'bagging_freq': 4,
#  'feature_fraction': 0.554404152192108,
#  'lambda_l1': 0.0015395748402496933,
#  'lambda_l2': 0.5766787304983864,
#  'learning_rate': 0.16373463943037975,
#  'max_bin': 447,
#  'max_depth': 3,
#  'min_child_samples': 17,
#  'min_data_in_leaf': 457,
#  'n_estimators': 4980,
#  'num_leaves': 2450}

# %%
best_params_df = pd.DataFrame([best_params]).transpose()
best_params_df.reset_index(inplace = True)
best_params_df.columns = ['Parameter', 'Value']
best_params_df
# Out:
#             Parameter        Value
# 0           lambda_l1     0.001540
# 1           lambda_l2     0.576679
# 2          num_leaves  2450.000000
# 3           max_depth     3.000000
# 4             max_bin   447.000000
# 5       learning_rate     0.163735
# 6    min_data_in_leaf   457.000000
# 7    feature_fraction     0.554404
# 8    bagging_fraction     0.926026
# 9        bagging_freq     4.000000
# 10  min_child_samples    17.000000
# 11       n_estimators  4980.000000

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size = 0.2,
                                                      stratify = y_train_full, random_state = 1)

lgbm_optuna = LGBMClassifier(**best_params)
lgbm_optuna.fit(X_train, y_train)
predictions = lgbm_optuna.predict(X_valid)
print(classification_report(predictions, y_valid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       768
#            1       0.95      0.94      0.94       788
#
#     accuracy                           0.94      1556
#    macro avg       0.94      0.94      0.94      1556
# weighted avg       0.94      0.94      0.94      1556
